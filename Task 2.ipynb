# %%
import cv2
import numpy as np

# %%
img = cv2.imread('DQ.jpg')

# %%
color = cv2.bilateralFilter(img, 9, 175, 175)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
gray = cv2.medianBlur(gray, 5)

# %%
edge = cv2.adaptiveThreshold(gray, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, 9, 9)

cartoon = cv2.bitwise_and(color, color, mask=edge)

cv2.imshow("Original", img)
cv2.imshow("Cartoon Effect", cartoon)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ![image.png](attachment:19a62cd2-004f-4ab4-970a-df9cfcac93fe.png)
# ![image.png](attachment:9a694f22-7895-4f7e-ba24-afe3604eda1e.png)
